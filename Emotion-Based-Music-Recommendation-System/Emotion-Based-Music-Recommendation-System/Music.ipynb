# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\bhara\anaconda3\lib\site-packages (1.26.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (5.1.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<10,>=7.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (4.24.1)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (13.5.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (4.5.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (3.1.35)
# Requirement already satisfied: pydeck<1,>=0.8 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\bhara\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\bhara\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhara\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\bhara\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhara\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhara\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\bhara\anaconda3\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\bhara\anaconda3\lib\site-packages (from tzlocal<5,>=1.1->streamlit) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhara\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\bhara\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\bhara\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhara\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit_webrtc
# Out:
# Collecting streamlit_webrtc
#   Obtaining dependency information for streamlit_webrtc from https://files.pythonhosted.org/packages/2e/18/d468e28786f847045238cd4d68bc0762b03014c5410e4828b918a10a34fa/streamlit_webrtc-0.47.0-py3-none-any.whl.metadata
#   Downloading streamlit_webrtc-0.47.0-py3-none-any.whl.metadata (18 kB)
# Collecting aiortc<2.0.0,>=1.4.0 (from streamlit_webrtc)
#   Downloading aiortc-1.5.0-cp311-cp311-win_amd64.whl (992 kB)
#      ---------------------------------------- 0.0/992.6 kB ? eta -:--:--
#      - -------------------------------------- 30.7/992.6 kB ? eta -:--:--
#      --- ----------------------------------- 92.2/992.6 kB 1.3 MB/s eta 0:00:01
#      ------- ------------------------------ 184.3/992.6 kB 1.4 MB/s eta 0:00:01
#      ----------- -------------------------- 307.2/992.6 kB 1.9 MB/s eta 0:00:01
#      ----------------- -------------------- 450.6/992.6 kB 2.2 MB/s eta 0:00:01
#      ----------------------- -------------- 614.4/992.6 kB 2.3 MB/s eta 0:00:01
#      -------------------------- ----------- 686.1/992.6 kB 2.3 MB/s eta 0:00:01
#      ------------------------------ ------- 798.7/992.6 kB 2.3 MB/s eta 0:00:01
#      ---------------------------------- --- 901.1/992.6 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------  983.0/992.6 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 992.6/992.6 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit_webrtc) (23.0)
# Requirement already satisfied: streamlit>=0.84.1 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit_webrtc) (1.26.0)
# Collecting aioice<1.0.0,>=0.9.0 (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Downloading aioice-0.9.0-py3-none-any.whl (24 kB)
# Collecting av<11.0.0,>=9.0.0 (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Downloading av-10.0.0-cp311-cp311-win_amd64.whl (25.3 MB)
#      ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#      ---------------------------------------- 0.2/25.3 MB 4.6 MB/s eta 0:00:06
#      ---------------------------------------- 0.2/25.3 MB 2.8 MB/s eta 0:00:10
#       --------------------------------------- 0.4/25.3 MB 2.7 MB/s eta 0:00:10
#       --------------------------------------- 0.6/25.3 MB 3.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.7/25.3 MB 3.0 MB/s eta 0:00:09
#      - -------------------------------------- 0.9/25.3 MB 3.3 MB/s eta 0:00:08
MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  24.7/25.3 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------  24.8/25.3 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  25.3/25.3 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  25.3/25.3 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  25.3/25.3 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------- 25.3/25.3 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0.0 in c:\users\bhara\anaconda3\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (1.15.1)
# Requirement already satisfied: cryptography>=2.2 in c:\users\bhara\anaconda3\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (41.0.2)
# Collecting google-crc32c>=1.1 (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Downloading google_crc32c-1.5.0-cp311-cp311-win_amd64.whl (27 kB)
# Collecting pyee>=9.0.0 (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Obtaining dependency information for pyee>=9.0.0 from https://files.pythonhosted.org/packages/d4/af/fc5f3e9b33da66122348227fdb01c09f8d49ceb77ec712ae413797b66a9e/pyee-11.0.0-py3-none-any.whl.metadata
#   Downloading pyee-11.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pylibsrtp>=0.5.6 (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Downloading pylibsrtp-0.8.0-cp311-cp311-win_amd64.whl (46 kB)
#      ---------------------------------------- 0.0/46.8 kB ? eta -:--:--
#      ---------------------------------------- 46.8/46.8 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pyopenssl>=23.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (23.2.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (5.1.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.24.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.5.3)
# Requirement already satisfied: pillow<10,>=7.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (4.24.1)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (11.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.0.1)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (2.8.2)
# Requirement already satisfied: requests<3,>=2.18 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (13.5.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (4.5.0)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (3.1.35)
# Requirement already satisfied: pydeck<1,>=0.8 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\bhara\anaconda3\lib\site-packages (from streamlit>=0.84.1->streamlit_webrtc) (2.1.6)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.9.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/f6/b4/0a9bee52c50f226a3cbfb54263d02bb421c7f2adc136520729c2c689c1e5/dnspython-2.4.2-py3-none-any.whl.metadata
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.9.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc)
#   Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: jinja2 in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (4.17.3)
# Requirement already satisfied: toolz in c:\users\bhara\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (0.12.0)
# Requirement already satisfied: pycparser in c:\users\bhara\anaconda3\lib\site-packages (from cffi>=1.0.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (2.21)
# Requirement already satisfied: colorama in c:\users\bhara\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit>=0.84.1->streamlit_webrtc) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit_webrtc) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\bhara\anaconda3\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit>=0.84.1->streamlit_webrtc) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhara\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.84.1->streamlit_webrtc) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\bhara\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit>=0.84.1->streamlit_webrtc) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit>=0.84.1->streamlit_webrtc) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit>=0.84.1->streamlit_webrtc) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit>=0.84.1->streamlit_webrtc) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhara\anaconda3\lib\site-packages (from requests<3,>=2.18->streamlit>=0.84.1->streamlit_webrtc) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bhara\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bhara\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (2.15.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\bhara\anaconda3\lib\site-packages (from tzlocal<5,>=1.1->streamlit>=0.84.1->streamlit_webrtc) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\bhara\anaconda3\lib\site-packages (from tzlocal<5,>=1.1->streamlit>=0.84.1->streamlit_webrtc) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit_webrtc) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhara\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\bhara\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\bhara\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bhara\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (0.1.0)
# Downloading streamlit_webrtc-0.47.0-py3-none-any.whl (874 kB)
#    ---------------------------------------- 0.0/874.7 kB ? eta -:--:--
#    ----------------------- --------------- 532.5/874.7 kB 11.1 MB/s eta 0:00:01
#    --------------------------------------  870.4/874.7 kB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 874.7/874.7 kB 9.2 MB/s eta 0:00:00
# Downloading pyee-11.0.0-py3-none-any.whl (15 kB)
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    ---------------------------------------- 300.4/300.4 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: ifaddr, av, pyee, google-crc32c, dnspython, pylibsrtp, aioice, aiortc, streamlit_webrtc
# Successfully installed aioice-0.9.0 aiortc-1.5.0 av-10.0.0 dnspython-2.4.2 google-crc32c-1.5.0 ifaddr-0.2.0 pyee-11.0.0 pylibsrtp-0.8.0 streamlit_webrtc-0.47.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe
# Out:
# Collecting mediapipe
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/b1/e9/5e59dec4830a9a0913cda2910f2c829065f447af7efc8338d6ff07c1f27c/mediapipe-0.10.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached mediapipe-0.10.3-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: absl-py in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (1.24.3)
# Collecting opencv-contrib-python (from mediapipe)
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/05/33/5a6436146bda09c69decc456cfb54f41d52fbcf558fe91e6df7bdde6cce0/opencv_contrib_python-4.8.0.76-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_contrib_python-4.8.0.76-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\bhara\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\bhara\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bhara\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\bhara\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\bhara\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Using cached mediapipe-0.10.3-cp311-cp311-win_amd64.whl (50.2 MB)
# Using cached opencv_contrib_python-4.8.0.76-cp37-abi3-win_amd64.whl (44.8 MB)
# Installing collected packages: opencv-contrib-python, sounddevice, mediapipe
# Successfully installed mediapipe-0.10.3 opencv-contrib-python-4.8.0.76 sounddevice-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from streamlit_webrtc import webrtc_streamer
import av
import cv2 
import numpy as np 
import mediapipe as mp 
from keras.models import load_model
import webbrowser

model  = load_model("model.h5")
label = np.load("labels.npy")
holistic = mp.solutions.holistic
hands = mp.solutions.hands
holis = holistic.Holistic()
drawing = mp.solutions.drawing_utils

st.header("Emotion Based Music Recommender")

if "run" not in st.session_state:
	st.session_state["run"] = "true"

try:
	emotion = np.load("emotion.npy")[0]
except:
	emotion=""

if not(emotion):
	st.session_state["run"] = "true"
else:
	st.session_state["run"] = "false"

class EmotionProcessor:
	def recv(self, frame):
		frm = frame.to_ndarray(format="bgr24")

		##############################
		frm = cv2.flip(frm, 1)

		res = holis.process(cv2.cvtColor(frm, cv2.COLOR_BGR2RGB))

		lst = []

		if res.face_landmarks:
			for i in res.face_landmarks.landmark:
				lst.append(i.x - res.face_landmarks.landmark[1].x)
				lst.append(i.y - res.face_landmarks.landmark[1].y)

			if res.left_hand_landmarks:
				for i in res.left_hand_landmarks.landmark:
					lst.append(i.x - res.left_hand_landmarks.landmark[8].x)
					lst.append(i.y - res.left_hand_landmarks.landmark[8].y)
			else:
				for i in range(42):
					lst.append(0.0)

			if res.right_hand_landmarks:
				for i in res.right_hand_landmarks.landmark:
					lst.append(i.x - res.right_hand_landmarks.landmark[8].x)
					lst.append(i.y - res.right_hand_landmarks.landmark[8].y)
			else:
				for i in range(42):
					lst.append(0.0)

			lst = np.array(lst).reshape(1,-1)

			pred = label[np.argmax(model.predict(lst))]

			print(pred)
			cv2.putText(frm, pred, (50,50),cv2.FONT_ITALIC, 1, (255,0,0),2)

			np.save("emotion.npy", np.array([pred]))

			
		drawing.draw_landmarks(frm, res.face_landmarks, holistic.FACEMESH_TESSELATION,
								landmark_drawing_spec=drawing.DrawingSpec(color=(0,0,255), thickness=-1, circle_radius=1),
								connection_drawing_spec=drawing.DrawingSpec(thickness=1))
		drawing.draw_landmarks(frm, res.left_hand_landmarks, hands.HAND_CONNECTIONS)
		drawing.draw_landmarks(frm, res.right_hand_landmarks, hands.HAND_CONNECTIONS)


		##############################

		return av.VideoFrame.from_ndarray(frm, format="bgr24")

lang = st.text_input("Language")
singer = st.text_input("singer")

if lang and singer and st.session_state["run"] != "false":
	webrtc_streamer(key="key", desired_playing_state=True,
				video_processor_factory=EmotionProcessor)

btn = st.button("Recommend me songs")

if btn:
	if not(emotion):
		st.warning("Please let me capture your emotion first")
		st.session_state["run"] = "true"
	else:
		webbrowser.open(f"https://www.youtube.com/results?search_query={lang}+{emotion}+song+{singer}")
		np.save("emotion.npy", np.array([""]))
		st.session_state["run"] = "false"
